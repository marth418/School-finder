# %%
import numpy as np
import pandas as pd
from geopy.geocoders import Nominatim
from sklearn.neighbors import KNeighborsClassifier
from geopy.distance import geodesic
import folium
from geopy import distance
from sklearn.cluster import KMeans
import matplotlib.cm as cm
import matplotlib.colors as colors
import usaddress

# %%
# Read dataset
data = pd.read_csv('new_data.csv')

# %%
data.head()
# Out:
#      NatEmis Province               Official_Institution_Name STATUS  \
# 0  700400770       GT           LYNNWOOD MANOR PRIVATE SCHOOL   OPEN
# 1  700401072       GT               ADVANCED COLLEGE BROOKLYN   OPEN
# 2  700400322       GT             NOOITGEDACHT AKADEMIE SKOOL   OPEN
# 3  700401082       GT         MELWOOD INSTITUTE OF TECHNOLOGY   OPEN
# 4  700400787       GT  BRITISH INTERNATIONAL COLLEGE-PRETORIA   OPEN
#
#         Sector            Phase_PED Specialisation   GIS_Long    GIS_Lat  \
# 0  INDEPENDENT       PRIMARY SCHOOL       ORDINARY  28.290307 -25.756580
# 1  INDEPENDENT      COMBINED SCHOOL       ORDINARY  28.248905 -25.768852
# 2  INDEPENDENT  INTERMEDIATE SCHOOL       ORDINARY  28.743439 -25.803851
# 3  INDEPENDENT     SECONDARY SCHOOL       ORDINARY  28.191676 -25.742973
# 4  INDEPENDENT     SECONDARY SCHOOL       ORDINARY  28.218095 -25.744145
#
#                            District Mun Name  ...   Ward_ID         Town_City  \
# 0  CITY OF TSHWANE METROPOLITAN MUNICIPALITY  ...  79900046    LYNNWOOD MANOR
# 1  CITY OF TSHWANE METROPOLITAN MUNICIPALITY  ...  79900082           BROOKLY
# 2  CITY OF TSHWANE METROPOLITAN MUNICIPALITY  ...  79900105    BRONKHORSPRUIT
# 3  CITY OF TSHWANE METROPOLITAN MUNICIPALITY  ...  79900058  PRETORIA CENTRAL
# 4  CITY OF TSHWANE METROPOLITAN MUNICIPALITY  ...  79900092          PRETORIA
#
#                                    StreetAddress  Telephone  Section21  \
# 0  99, BRAMPTON STREET, LYNNWOOD MANOR, PRETORIA  123489998         NO
# 1           415, MARAIS ROAD, BROOKLYN, PRETORIA  120301031         NO
# 2  17, MARK STREET, NOOITGEDACHT, BRONKHORSPRUIT  732577542         NO
# 3     274,  JOHANNES RAMOKHOASE STREET, PRETORIA  123270294         NO
# 4         774, CHURCH STREET, EASTWOOD, PRETORIA  117067775         NO
#
#   School Fees Urban_Rural       Town_Suburb      Towns/suburb  \
# 0         Yes       URBAN    LYNNWOOD MANOR    Lynnwood Manor
# 1         Yes       URBAN         BROOKLYN          Brooklyn
# 2         Yes       URBAN  BRONKHORSTSPRUIT  Bronkhorstspruit
# 3         Yes       URBAN  PRETORIA CENTRAL  Pretoria Central
# 4         Yes       URBAN          EASTWOOD          Eastwood
#
#           suburb_coordinates
# 0  (-25.7630556, 28.2811111)
# 1        (-25.7646, 28.2393)
# 2        (-25.8084, 28.7081)
# 3  (-25.7518426, 28.1899743)
# 4        (-25.7411, 28.2198)
#
# [5 rows x 21 columns]

# %%
data.columns
# Out:
# Index(['NatEmis', 'Province', 'Official_Institution_Name', 'STATUS', 'Sector',
#        'Phase_PED', 'Specialisation', 'GIS_Long', 'GIS_Lat',
#        'District Mun Name', 'Local MunName', 'Ward_ID', 'Town_City',
#        'StreetAddress', 'Telephone', 'Section21', 'School Fees', 'Urban_Rural',
#        'Town_Suburb', 'Towns/suburb', 'suburb_coordinates'],
#       dtype='object')

# %%
data = data.apply(lambda x: x.str.lower() if x.dtype == "object" else x)

# %%
data = data.apply(lambda x: x.str.title() if x.dtype == "object" else x)

# %%
data.head(5)
# Out:
#      NatEmis Province               Official_Institution_Name STATUS  \
# 0  700400770       Gt           Lynnwood Manor Private School   Open
# 1  700401072       Gt               Advanced College Brooklyn   Open
# 2  700400322       Gt             Nooitgedacht Akademie Skool   Open
# 3  700401082       Gt         Melwood Institute Of Technology   Open
# 4  700400787       Gt  British International College-Pretoria   Open
#
#         Sector            Phase_PED Specialisation   GIS_Long    GIS_Lat  \
# 0  Independent       Primary School       Ordinary  28.290307 -25.756580
# 1  Independent      Combined School       Ordinary  28.248905 -25.768852
# 2  Independent  Intermediate School       Ordinary  28.743439 -25.803851
# 3  Independent     Secondary School       Ordinary  28.191676 -25.742973
# 4  Independent     Secondary School       Ordinary  28.218095 -25.744145
#
#                            District Mun Name  ...   Ward_ID         Town_City  \
# 0  City Of Tshwane Metropolitan Municipality  ...  79900046    Lynnwood Manor
# 1  City Of Tshwane Metropolitan Municipality  ...  79900082           Brookly
# 2  City Of Tshwane Metropolitan Municipality  ...  79900105    Bronkhorspruit
# 3  City Of Tshwane Metropolitan Municipality  ...  79900058  Pretoria Central
# 4  City Of Tshwane Metropolitan Municipality  ...  79900092          Pretoria
#
#                                    StreetAddress  Telephone  Section21  \
# 0  99, Brampton Street, Lynnwood Manor, Pretoria  123489998         No
# 1           415, Marais Road, Brooklyn, Pretoria  120301031         No
# 2  17, Mark Street, Nooitgedacht, Bronkhorspruit  732577542         No
# 3     274,  Johannes Ramokhoase Street, Pretoria  123270294         No
# 4         774, Church Street, Eastwood, Pretoria  117067775         No
#
#   School Fees Urban_Rural       Town_Suburb      Towns/suburb  \
# 0         Yes       Urban    Lynnwood Manor    Lynnwood Manor
# 1         Yes       Urban         Brooklyn          Brooklyn
# 2         Yes       Urban  Bronkhorstspruit  Bronkhorstspruit
# 3         Yes       Urban  Pretoria Central  Pretoria Central
# 4         Yes       Urban          Eastwood          Eastwood
#
#           suburb_coordinates
# 0  (-25.7630556, 28.2811111)
# 1        (-25.7646, 28.2393)
# 2        (-25.8084, 28.7081)
# 3  (-25.7518426, 28.1899743)
# 4        (-25.7411, 28.2198)
#
# [5 rows x 21 columns]

# %%
data.shape
# Out:
# (700, 21)

# %%
# Check for null values
data.isna().sum()
# Out:
# NatEmis                      0
# Province                     0
# Official_Institution_Name    0
# STATUS                       0
# Sector                       0
# Phase_PED                    0
# Specialisation               0
# GIS_Long                     0
# GIS_Lat                      0
# District Mun Name            0
# Local MunName                0
# Ward_ID                      0
# Town_City                    0
# StreetAddress                0
# Telephone                    0
# Section21                    0
# School Fees                  0
# Urban_Rural                  0
# Town_Suburb                  0
# Towns/suburb                 0
# suburb_coordinates           0
# dtype: int64

# %%
# Check for duplicates
duplicate = data[data.duplicated()]
print("Duplicate Rows :")
# Out:
# Duplicate Rows :

# %%
# Split the suburb coordinates
data[['suburb_Latitude', 'suburb_longitude']] = data['suburb_coordinates'].str.split(', ', expand=True)

# %%
# remove suburb coordinates column
data = data.drop(['suburb_coordinates', 'Town_City', 'Town_Suburb'], axis=1)
data.columns
# Out:
# Index(['NatEmis', 'Province', 'Official_Institution_Name', 'STATUS', 'Sector',
#        'Phase_PED', 'Specialisation', 'GIS_Long', 'GIS_Lat',
#        'District Mun Name', 'Local MunName', 'Ward_ID', 'StreetAddress',
#        'Telephone', 'Section21', 'School Fees', 'Urban_Rural', 'Towns/suburb',
#        'suburb_Latitude', 'suburb_longitude'],
#       dtype='object')

# %%
# Strip unwanted characters
data['suburb_Latitude'] = data['suburb_Latitude'].str[1:]
data['suburb_longitude'] = data['suburb_longitude'].str[:-1]
data.head()
# Out:
#      NatEmis Province               Official_Institution_Name STATUS  \
# 0  700400770       Gt           Lynnwood Manor Private School   Open
# 1  700401072       Gt               Advanced College Brooklyn   Open
# 2  700400322       Gt             Nooitgedacht Akademie Skool   Open
# 3  700401082       Gt         Melwood Institute Of Technology   Open
# 4  700400787       Gt  British International College-Pretoria   Open
#
#         Sector            Phase_PED Specialisation   GIS_Long    GIS_Lat  \
# 0  Independent       Primary School       Ordinary  28.290307 -25.756580
# 1  Independent      Combined School       Ordinary  28.248905 -25.768852
# 2  Independent  Intermediate School       Ordinary  28.743439 -25.803851
# 3  Independent     Secondary School       Ordinary  28.191676 -25.742973
# 4  Independent     Secondary School       Ordinary  28.218095 -25.744145
#
#                            District Mun Name  \
# 0  City Of Tshwane Metropolitan Municipality
# 1  City Of Tshwane Metropolitan Municipality
# 2  City Of Tshwane Metropolitan Municipality
# 3  City Of Tshwane Metropolitan Municipality
# 4  City Of Tshwane Metropolitan Municipality
#
#                                Local MunName   Ward_ID  \
# 0  City Of Tshwane Metropolitan Municipality  79900046
# 1  City Of Tshwane Metropolitan Municipality  79900082
# 2  City Of Tshwane Metropolitan Municipality  79900105
# 3  City Of Tshwane Metropolitan Municipality  79900058
# 4  City Of Tshwane Metropolitan Municipality  79900092
#
#                                    StreetAddress  Telephone Section21  \
# 0  99, Brampton Street, Lynnwood Manor, Pretoria  123489998        No
# 1           415, Marais Road, Brooklyn, Pretoria  120301031        No
# 2  17, Mark Street, Nooitgedacht, Bronkhorspruit  732577542        No
# 3     274,  Johannes Ramokhoase Street, Pretoria  123270294        No
# 4         774, Church Street, Eastwood, Pretoria  117067775        No
#
#   School Fees Urban_Rural      Towns/suburb suburb_Latitude suburb_longitude
# 0         Yes       Urban    Lynnwood Manor     -25.7630556       28.2811111
# 1         Yes       Urban         Brooklyn         -25.7646          28.2393
# 2         Yes       Urban  Bronkhorstspruit        -25.8084          28.7081
# 3         Yes       Urban  Pretoria Central     -25.7518426       28.1899743
# 4         Yes       Urban          Eastwood        -25.7411          28.2198

# %%
# Check for datatypes
print(data.dtypes)
# Out:
# NatEmis                        int64
# Province                      object
# Official_Institution_Name     object
# STATUS                        object
# Sector                        object
# Phase_PED                     object
# Specialisation                object
# GIS_Long                     float64
# GIS_Lat                      float64
# District Mun Name             object
# Local MunName                 object
# Ward_ID                        int64
# StreetAddress                 object
# Telephone                      int64
# Section21                     object
# School Fees                   object
# Urban_Rural                   object
# Towns/suburb                  object
# suburb_Latitude               object
# suburb_longitude              object
# dtype: object

# %%
# Change the town coordinates datatype from object to float
data['suburb_Latitude'] = pd.to_numeric(data['suburb_Latitude'], errors='coerce')
data['suburb_longitude'] = pd.to_numeric(data['suburb_longitude'], errors='coerce')
print(data.dtypes)
# Out:
# NatEmis                        int64
# Province                      object
# Official_Institution_Name     object
# STATUS                        object
# Sector                        object
# Phase_PED                     object
# Specialisation                object
# GIS_Long                     float64
# GIS_Lat                      float64
# District Mun Name             object
# Local MunName                 object
# Ward_ID                        int64
# StreetAddress                 object
# Telephone                      int64
# Section21                     object
# School Fees                   object
# Urban_Rural                   object
# Towns/suburb                  object
# suburb_Latitude              float64
# suburb_longitude             float64
# dtype: object

# %%
# Check for null values
print(data.isna().sum())
# Out:
# NatEmis                      0
# Province                     0
# Official_Institution_Name    0
# STATUS                       0
# Sector                       0
# Phase_PED                    0
# Specialisation               0
# GIS_Long                     0
# GIS_Lat                      0
# District Mun Name            0
# Local MunName                0
# Ward_ID                      0
# StreetAddress                0
# Telephone                    0
# Section21                    0
# School Fees                  0
# Urban_Rural                  0
# Towns/suburb                 0
# suburb_Latitude              0
# suburb_longitude             0
# dtype: int64

# %%
suburbs_town_df = data[['Province', 'Towns/suburb','suburb_Latitude', 'suburb_longitude']].copy()
suburbs_town_df.head(2)
# Out:
#   Province    Towns/suburb  suburb_Latitude  suburb_longitude
# 0       Gt  Lynnwood Manor       -25.763056         28.281111
# 1       Gt       Brooklyn        -25.764600         28.239300

# %%
# Pretoria Coordinates
latitude = -25.7479
longitude = 28.2293

# %% [markdown]
# ##### Map of Suburbs/Towns

# %%
suburb_data = suburbs_town_df
map_pretoria = folium.Map(location=[latitude, longitude], zoom_start=11)

# add markers to map
for lat, lng, label in zip(suburb_data['suburb_Latitude'], suburb_data['suburb_longitude'], suburb_data['Towns/suburb']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_pretoria)

map_pretoria
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c0824ab10ba34e7ffc943fa203372d68 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c0824ab10ba34e7ffc943fa203372d68&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c0824ab10ba34e7ffc943fa203372d68 = L.map(
#                 &quot;map_c0824ab10ba34e7ffc943fa203372d68&quot;,
#                 {
#                     center: [-25.7479, 28.2293],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_afe0f0f57268bae0056e462a164b2ab4 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_c0824ab10ba34e7ffc943fa203372d68);
#
#
#             var circle_marker_a91853e80d46e90826d218184e8f7db7 = L.circleMarker(
#                 [-25.7630556, 28.2811111],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3186cc&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_c0824ab10ba34e7ffc943fa203372d68);
#
#
#         var popup_d54ba42d51eb5b48be388c5f10fad772 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c7c5ed297882492ba80e40f98db45164 = $(`&lt;div id=&quot;html_c7c5ed297882492ba80e40f98db45164&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Lynnwood Manor&lt;/div&gt;`)[0];
#                 popup_d54ba42d51eb5b48be388c5f10fad772.setContent(html_c7c5ed297882492ba80e40f98db45164);
#
#
#
#         circle_marker_a91853e80d46e90826d218184e8f7db7.bindPopup(popup_d54ba42d51eb5b48be388c5f10fad772)
#         ;
#
#
#
#
#             var circle_marker_d5c0eef269914d5b8ca04bbabb885bd1 = L.circleMarker(
#                 [-25.7646, 28.2393],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3186cc&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_c0824ab10ba34e7ffc943fa203372d68);
#
#
#         var popup_182fd95f76429b20111fc906beb67f75 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4e50a974497bbc789b125d28878fd72e = $(`&lt;div id=&quot;html_4e50a974497bbc789b125d28878fd72e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Brooklyn &lt;/div&gt;`)[0];
#                 popup_182fd95f76429b20111fc906beb67f75.setContent(html_4e50a974497bbc789b125d28878fd72e);
#
#
#
#         circle_marker_d5c0eef269914d5b8ca04bbabb885bd1.bindPopup(popup_182fd95f76429b20111fc906beb67f75)
#         ;
#
#
#
#
#             var circle_marker_71e26ed894e3440177e0291630b33965 = L.circleMarker(
#                 [-25.8084, 28.7081],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3186cc&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_c0824ab10ba34e7ffc943fa203372d68);
#
#
#         var popup_dde44d7e37662483801e4c4824bcafb6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_20536811d8bacbecadbc53c0266e0cb9 = $(`&lt;div id=&quot;html_20536811d8bacbecadbc53c0266e0cb9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Bronkhorstspruit&lt;/div&gt;`)[0];
#                 popup_dde44d7e37662483801e4c4824bcafb6.setContent(html_20536811d8bacbecadbc53c0266e0cb9);
#
#
#
#         circle_marker_71e26ed894e3440177e0291630b33965.bindPopup(popup_dde44d7e37662483801e4c4824bcafb6)
#         ;
#
#
#
#
#             var circle_marker_c93e4c0a238c69b2bce7ebb7ffa0cf04 = L.circleMarker(
#                 [-25.7518426, 28.1899743],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: t

# %%
data.columns
# Out:
# Index(['NatEmis', 'Province', 'Official_Institution_Name', 'STATUS', 'Sector',
#        'Phase_PED', 'Specialisation', 'GIS_Long', 'GIS_Lat',
#        'District Mun Name', 'Local MunName', 'Ward_ID', 'StreetAddress',
#        'Telephone', 'Section21', 'School Fees', 'Urban_Rural', 'Towns/suburb',
#        'suburb_Latitude', 'suburb_longitude'],
#       dtype='object')

# %%
school_data = data[['Province','Towns/suburb','suburb_Latitude','suburb_longitude','Official_Institution_Name', 'GIS_Lat', 'GIS_Long']].copy()

# %%
school_data.head()
# Out:
#   Province      Towns/suburb  suburb_Latitude  suburb_longitude  \
# 0       Gt    Lynnwood Manor       -25.763056         28.281111
# 1       Gt         Brooklyn        -25.764600         28.239300
# 2       Gt  Bronkhorstspruit       -25.808400         28.708100
# 3       Gt  Pretoria Central       -25.751843         28.189974
# 4       Gt          Eastwood       -25.741100         28.219800
#
#                 Official_Institution_Name    GIS_Lat   GIS_Long
# 0           Lynnwood Manor Private School -25.756580  28.290307
# 1               Advanced College Brooklyn -25.768852  28.248905
# 2             Nooitgedacht Akademie Skool -25.803851  28.743439
# 3         Melwood Institute Of Technology -25.742973  28.191676
# 4  British International College-Pretoria -25.744145  28.218095

# %% [markdown]
# ##### Map of Schools in Pretoria

# %%
map_schools = folium.Map(location=[latitude, longitude], zoom_start=11)

# add markers to map
for lat, lng, label in zip(school_data['GIS_Lat'], school_data['GIS_Long'], school_data['Official_Institution_Name']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=2,
        popup=label,
        color='red',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_schools)  
    
map_schools
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ed5d14f512b684c36dd82c4c904a078a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ed5d14f512b684c36dd82c4c904a078a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ed5d14f512b684c36dd82c4c904a078a = L.map(
#                 &quot;map_ed5d14f512b684c36dd82c4c904a078a&quot;,
#                 {
#                     center: [-25.7479, 28.2293],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_232d30ba410fec8afbaac5bc50e2f061 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ed5d14f512b684c36dd82c4c904a078a);
#
#
#             var circle_marker_34227bafe9adac57c569596484145280 = L.circleMarker(
#                 [-25.75658, 28.290307],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3186cc&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_ed5d14f512b684c36dd82c4c904a078a);
#
#
#         var popup_39c50b044ba7eb416d7b204aaa2141ac = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3d6e1e1b8fb857523791a5f76137c136 = $(`&lt;div id=&quot;html_3d6e1e1b8fb857523791a5f76137c136&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Lynnwood Manor Private School&lt;/div&gt;`)[0];
#                 popup_39c50b044ba7eb416d7b204aaa2141ac.setContent(html_3d6e1e1b8fb857523791a5f76137c136);
#
#
#
#         circle_marker_34227bafe9adac57c569596484145280.bindPopup(popup_39c50b044ba7eb416d7b204aaa2141ac)
#         ;
#
#
#
#
#             var circle_marker_ba01b76a742b847a5bc3f3df7b3dacfe = L.circleMarker(
#                 [-25.768852, 28.248905],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3186cc&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_ed5d14f512b684c36dd82c4c904a078a);
#
#
#         var popup_3815b30bebe5a5f8c97fb3798adb88eb = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0de42f241dd1781bf9943903029e28b5 = $(`&lt;div id=&quot;html_0de42f241dd1781bf9943903029e28b5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Advanced College Brooklyn&lt;/div&gt;`)[0];
#                 popup_3815b30bebe5a5f8c97fb3798adb88eb.setContent(html_0de42f241dd1781bf9943903029e28b5);
#
#
#
#         circle_marker_ba01b76a742b847a5bc3f3df7b3dacfe.bindPopup(popup_3815b30bebe5a5f8c97fb3798adb88eb)
#         ;
#
#
#
#
#             var circle_marker_062bcb7cdf6ed58cef8b6b860d1ddc68 = L.circleMarker(
#                 [-25.803851318, 28.743439411],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3186cc&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_ed5d14f512b684c36dd82c4c904a078a);
#
#
#         var popup_71381e5b01b42de9df29a93d855a8bc6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6b5aab392d15d777f55daed02d334043 = $(`&lt;div id=&quot;html_6b5aab392d15d777f55daed02d334043&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Nooitgedacht Akademie Skool&lt;/div&gt;`)[0];
#                 popup_71381e5b01b42de9df29a93d855a8bc6.setContent(html_6b5aab392d15d777f55daed02d334043);
#
#
#
#         circle_marker_062bcb7cdf6ed58cef8b6b860d1ddc68.bindPopup(popup_71381e5b01b42de9df29a93d855a8bc6)
#         ;
#
#
#
#
#             var circle_marker_bfbf2e5e605e4c3835c2f5fdc8892cea = L.circleMarker(
#                 [-25.742973, 28.191676],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &q

# %%
from sklearn.neighbors import BallTree

# %%
X = data[['GIS_Lat', 'GIS_Long']].values
tree = BallTree(X, leaf_size=2)

# %%
def find_nearest_schools(suburb_name, k=3):
    # Find the suburb latitude and longitude
    suburb = data[data['Towns/suburb'] == suburb_name].iloc[0]
    suburb_lat, suburb_lon = suburb['suburb_Latitude'], suburb['suburb_longitude']
    
    # Query the BallTree for the k nearest schools
    _, idxs = tree.query([[suburb_lat, suburb_lon]], k=5)
    nearest_schools = data.iloc[idxs[0]][['Official_Institution_Name']]
    
    # Concatenate the names of the nearest schools into a single string with line breaks
    return '\n'.join(f"{i+1}. {name}" for i, name in enumerate(nearest_schools['Official_Institution_Name']))

# %%
find_nearest_schools('Pretoria Central')
# Out:
# '1. Tshwane Secondary School\n2. Greenwood College\n3. St Aquinas-Pretoria Campus\n4. Hamilton Primary School\n5. Loreto Convent School'

# %%
data.columns
# Out:
# Index(['NatEmis', 'Province', 'Official_Institution_Name', 'STATUS', 'Sector',
#        'Phase_PED', 'Specialisation', 'GIS_Long', 'GIS_Lat',
#        'District Mun Name', 'Local MunName', 'Ward_ID', 'StreetAddress',
#        'Telephone', 'Section21', 'School Fees', 'Urban_Rural', 'Towns/suburb',
#        'suburb_Latitude', 'suburb_longitude'],
#       dtype='object')

# %%
def get_closest_schools(suburb_name, data):
    # Filter the dataframe to include only the suburb of interest
    suburb_df = data[data['Towns/suburb'] == suburb_name]
    
    # Get the latitude and longitude of the suburb
    suburb_lat = suburb_df.iloc[0]['suburb_Latitude']
    suburb_lon = suburb_df.iloc[0]['suburb_longitude']
    
    # Create a list to hold the distances between the suburb and each school
    distances = []
    
    # Iterate over the schools in the dataframe
    for index, row in data.iterrows():
        # Get the latitude and longitude of the school
        school_lat = row['GIS_Lat']
        school_lon = row['GIS_Long']
        
        # Calculate the distance between the suburb and the school
        distance = geodesic((suburb_lat, suburb_lon), (school_lat, school_lon)).km
        
        # Add the distance to the list
        distances.append(distance)
    
    # Add a new column to the dataframe with the distances
    data['Distance'] = distances
    
    # Sort the dataframe by distance
    closest_schools = data.sort_values(by='Distance').head(5)
    
    # Create a map centered on the suburb
    map = folium.Map(location=[suburb_lat, suburb_lon], zoom_start=13)
    
    # Add a marker for the suburb
    folium.Marker(location=[suburb_lat, suburb_lon], popup=suburb_name).add_to(map)
    
    # Add markers for the closest schools
    for index, row in closest_schools.iterrows():
        folium.Marker(location=[row['GIS_Lat'], row['GIS_Long']], popup=row['Official_Institution_Name']).add_to(map)
    
    # Return the map
    return map

# %%
get_closest_schools('Brooklyn', data)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1d4f6fb2fa89fc5cfb1d71a1186ba8a8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1d4f6fb2fa89fc5cfb1d71a1186ba8a8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1d4f6fb2fa89fc5cfb1d71a1186ba8a8 = L.map(
#                 &quot;map_1d4f6fb2fa89fc5cfb1d71a1186ba8a8&quot;,
#                 {
#                     center: [-25.7646, 28.2393],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c28f22cdf55268117a79bb4247d3e407 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_1d4f6fb2fa89fc5cfb1d71a1186ba8a8);
#
#
#             var marker_26e153012def2c0623399afe94ef27f0 = L.marker(
#                 [-25.7646, 28.2393],
#                 {}
#             ).addTo(map_1d4f6fb2fa89fc5cfb1d71a1186ba8a8);
#
#
#         var popup_dfd0ab5f14aec029872a448e27b6546d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9bd3963749b23c9f3481906bf16817fd = $(`&lt;div id=&quot;html_9bd3963749b23c9f3481906bf16817fd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Brooklyn&lt;/div&gt;`)[0];
#                 popup_dfd0ab5f14aec029872a448e27b6546d.setContent(html_9bd3963749b23c9f3481906bf16817fd);
#
#
#
#         marker_26e153012def2c0623399afe94ef27f0.bindPopup(popup_dfd0ab5f14aec029872a448e27b6546d)
#         ;
#
#
#
#
#             var marker_e63996f160b2f8028997e77681007a97 = L.marker(
#                 [-25.76358036, 28.24300309],
#                 {}
#             ).addTo(map_1d4f6fb2fa89fc5cfb1d71a1186ba8a8);
#
#
#         var popup_12d074927d6023f312287af0c8bcd1b4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_214b1fe2f813597b457f0d300836629c = $(`&lt;div id=&quot;html_214b1fe2f813597b457f0d300836629c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Pretoria Preparatory School&lt;/div&gt;`)[0];
#                 popup_12d074927d6023f312287af0c8bcd1b4.setContent(html_214b1fe2f813597b457f0d300836629c);
#
#
#
#         marker_e63996f160b2f8028997e77681007a97.bindPopup(popup_12d074927d6023f312287af0c8bcd1b4)
#         ;
#
#
#
#
#             var marker_a35d46f60d5a3e1e44b4296c35c6650c = L.marker(
#                 [-25.76444336, 28.2433069],
#                 {}
#             ).addTo(map_1d4f6fb2fa89fc5cfb1d71a1186ba8a8);
#
#
#         var popup_12c1ccf255cf1d5757aab20a588bc6e2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_21524be9fda980fc9cf881f79d8972f3 = $(`&lt;div id=&quot;html_21524be9fda980fc9cf881f79d8972f3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Brooklyn Primary School&lt;/div&gt;`)[0];
#                 popup_12c1ccf255cf1d5757aab20a588bc6e2.setContent(html_21524be9fda980fc9cf881f79d8972f3);
#
#
#
#         marker_a35d46f60d5a3e1e44b4296c35c6650c.bindPopup(popup_12c1ccf255cf1d5757aab20a588bc6e2)
#         ;
#
#
#
#
#             var marker_ee3190f85780c24b6e95e00161057cd2 = L.marker(
#                 [-25.766248333, 28.232081667],
#                 {}
#             ).addTo(map_1d4f6fb2fa89fc5cfb1d71a1186ba8a8);
#
#
#         var popup_e63c924050dd73dede3730a76856c649 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5d02ae38ee71ba8ebf747305f540ae81 = $(`&lt;div id=&quot;html_5d02ae38ee71ba8ebf747305f540ae81&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Waterkloof House Preparatory&lt;/div&gt;`)[0];
#                 popup_e63c924050dd73dede3730a76856c649.setContent(html_5d02ae38ee71ba8ebf747305f540ae81);
#
#
#
#         marker_ee3190f85780c24b6e95e00161057cd2.bindPopup(popup_e63c924050dd73dede3730a76856c649)
#         ;
#
#
#
#
#             var marker_5e7e87dcfc9222b0796287b30301305f = L.marker(
#                 [-25.755424135, 28.241804504],
#                 {}
#             ).addTo(map_1d4f6fb2fa89fc5cfb1d71a1186ba8a8);
#
#
#         var popup_68f088d479bbff07e1003e8dd2bed82f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ce5d6b5143c6b97185ed6dfbd7ba41f0 = $(`&lt;div id=&quot;html_ce5d6b5143c6b97185ed6dfbd7ba41f0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;St Mary&#x27;S Diocesan School For Girls&lt;/div&gt;`)[0];
#                 popup_68f088d479bbff07e1003e8dd2bed82f.setContent(html_ce5d6b5143c6b97185ed6dfbd7ba41f0);
#
#
#
#         marker_5e7e87dcfc9222b0796287b30301305f.bindPopup(popup_68f088d479bbff07e1003e8dd2bed82f)
#         ;
#
#
#
#
#             var marker_c6ead7ca7f79220c8d216fd
