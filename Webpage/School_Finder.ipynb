# %%
import numpy as np
import pandas as pd
from geopy.geocoders import Nominatim
from sklearn.neighbors import KNeighborsClassifier
from geopy.distance import geodesic
import folium
from sklearn.utils import murmurhash
from geopy import distance
from sklearn.cluster import KMeans
import matplotlib.cm as cm
import matplotlib.colors as colors
import usaddress

# %%
# Read dataset
data = pd.read_csv('new_data.csv')

# %%
data.head()
# Out:
#      NatEmis Province               Official_Institution_Name STATUS  \
# 0  700400770       GT           LYNNWOOD MANOR PRIVATE SCHOOL   OPEN
# 1  700401072       GT               ADVANCED COLLEGE BROOKLYN   OPEN
# 2  700400322       GT             NOOITGEDACHT AKADEMIE SKOOL   OPEN
# 3  700401082       GT         MELWOOD INSTITUTE OF TECHNOLOGY   OPEN
# 4  700400787       GT  BRITISH INTERNATIONAL COLLEGE-PRETORIA   OPEN
#
#         Sector            Phase_PED Specialisation   GIS_Long    GIS_Lat  \
# 0  INDEPENDENT       PRIMARY SCHOOL       ORDINARY  28.290307 -25.756580
# 1  INDEPENDENT      COMBINED SCHOOL       ORDINARY  28.248905 -25.768852
# 2  INDEPENDENT  INTERMEDIATE SCHOOL       ORDINARY  28.743439 -25.803851
# 3  INDEPENDENT     SECONDARY SCHOOL       ORDINARY  28.191676 -25.742973
# 4  INDEPENDENT     SECONDARY SCHOOL       ORDINARY  28.218095 -25.744145
#
#                            District Mun Name  ...   Ward_ID         Town_City  \
# 0  CITY OF TSHWANE METROPOLITAN MUNICIPALITY  ...  79900046    LYNNWOOD MANOR
# 1  CITY OF TSHWANE METROPOLITAN MUNICIPALITY  ...  79900082           BROOKLY
# 2  CITY OF TSHWANE METROPOLITAN MUNICIPALITY  ...  79900105    BRONKHORSPRUIT
# 3  CITY OF TSHWANE METROPOLITAN MUNICIPALITY  ...  79900058  PRETORIA CENTRAL
# 4  CITY OF TSHWANE METROPOLITAN MUNICIPALITY  ...  79900092          PRETORIA
#
#                                    StreetAddress  Telephone  Section21  \
# 0  99, BRAMPTON STREET, LYNNWOOD MANOR, PRETORIA  123489998         NO
# 1           415, MARAIS ROAD, BROOKLYN, PRETORIA  120301031         NO
# 2  17, MARK STREET, NOOITGEDACHT, BRONKHORSPRUIT  732577542         NO
# 3     274,  JOHANNES RAMOKHOASE STREET, PRETORIA  123270294         NO
# 4         774, CHURCH STREET, EASTWOOD, PRETORIA  117067775         NO
#
#   School Fees Urban_Rural       Town_Suburb      Towns/suburb  \
# 0         Yes       URBAN    LYNNWOOD MANOR    Lynnwood Manor
# 1         Yes       URBAN         BROOKLYN          Brooklyn
# 2         Yes       URBAN  BRONKHORSTSPRUIT  Bronkhorstspruit
# 3         Yes       URBAN  PRETORIA CENTRAL  Pretoria Central
# 4         Yes       URBAN          EASTWOOD          Eastwood
#
#           suburb_coordinates
# 0  (-25.7630556, 28.2811111)
# 1        (-25.7646, 28.2393)
# 2        (-25.8084, 28.7081)
# 3  (-25.7518426, 28.1899743)
# 4        (-25.7411, 28.2198)
#
# [5 rows x 21 columns]

# %%
data.columns
# Out:
# Index(['NatEmis', 'Province', 'Official_Institution_Name', 'STATUS', 'Sector',
#        'Phase_PED', 'Specialisation', 'GIS_Long', 'GIS_Lat',
#        'District Mun Name', 'Local MunName', 'Ward_ID', 'Town_City',
#        'StreetAddress', 'Telephone', 'Section21', 'School Fees', 'Urban_Rural',
#        'Town_Suburb', 'Towns/suburb', 'suburb_coordinates'],
#       dtype='object')

# %%
data = data.apply(lambda x: x.str.lower() if x.dtype == "object" else x)

# %%
data = data.apply(lambda x: x.str.title() if x.dtype == "object" else x)

# %%
data.head(5)
# Out:
#      NatEmis Province               Official_Institution_Name STATUS  \
# 0  700400770       Gt           Lynnwood Manor Private School   Open
# 1  700401072       Gt               Advanced College Brooklyn   Open
# 2  700400322       Gt             Nooitgedacht Akademie Skool   Open
# 3  700401082       Gt         Melwood Institute Of Technology   Open
# 4  700400787       Gt  British International College-Pretoria   Open
#
#         Sector            Phase_PED Specialisation   GIS_Long    GIS_Lat  \
# 0  Independent       Primary School       Ordinary  28.290307 -25.756580
# 1  Independent      Combined School       Ordinary  28.248905 -25.768852
# 2  Independent  Intermediate School       Ordinary  28.743439 -25.803851
# 3  Independent     Secondary School       Ordinary  28.191676 -25.742973
# 4  Independent     Secondary School       Ordinary  28.218095 -25.744145
#
#                            District Mun Name  ...   Ward_ID         Town_City  \
# 0  City Of Tshwane Metropolitan Municipality  ...  79900046    Lynnwood Manor
# 1  City Of Tshwane Metropolitan Municipality  ...  79900082           Brookly
# 2  City Of Tshwane Metropolitan Municipality  ...  79900105    Bronkhorspruit
# 3  City Of Tshwane Metropolitan Municipality  ...  79900058  Pretoria Central
# 4  City Of Tshwane Metropolitan Municipality  ...  79900092          Pretoria
#
#                                    StreetAddress  Telephone  Section21  \
# 0  99, Brampton Street, Lynnwood Manor, Pretoria  123489998         No
# 1           415, Marais Road, Brooklyn, Pretoria  120301031         No
# 2  17, Mark Street, Nooitgedacht, Bronkhorspruit  732577542         No
# 3     274,  Johannes Ramokhoase Street, Pretoria  123270294         No
# 4         774, Church Street, Eastwood, Pretoria  117067775         No
#
#   School Fees Urban_Rural       Town_Suburb      Towns/suburb  \
# 0         Yes       Urban    Lynnwood Manor    Lynnwood Manor
# 1         Yes       Urban         Brooklyn          Brooklyn
# 2         Yes       Urban  Bronkhorstspruit  Bronkhorstspruit
# 3         Yes       Urban  Pretoria Central  Pretoria Central
# 4         Yes       Urban          Eastwood          Eastwood
#
#           suburb_coordinates
# 0  (-25.7630556, 28.2811111)
# 1        (-25.7646, 28.2393)
# 2        (-25.8084, 28.7081)
# 3  (-25.7518426, 28.1899743)
# 4        (-25.7411, 28.2198)
#
# [5 rows x 21 columns]

# %%
data.shape
# Out:
# (700, 21)

# %%
# Check for null values
data.isna().sum()
# Out:
# NatEmis                      0
# Province                     0
# Official_Institution_Name    0
# STATUS                       0
# Sector                       0
# Phase_PED                    0
# Specialisation               0
# GIS_Long                     0
# GIS_Lat                      0
# District Mun Name            0
# Local MunName                0
# Ward_ID                      0
# Town_City                    0
# StreetAddress                0
# Telephone                    0
# Section21                    0
# School Fees                  0
# Urban_Rural                  0
# Town_Suburb                  0
# Towns/suburb                 0
# suburb_coordinates           0
# dtype: int64

# %%
# Check for duplicates
duplicate = data[data.duplicated()]
print("Duplicate Rows :")
# Out:
# Duplicate Rows :

# %%
# Split the suburb coordinates
data[['suburb_Latitude', 'suburb_longitude']] = data['suburb_coordinates'].str.split(', ', expand=True)

# %%
# remove suburb coordinates column
data = data.drop(['suburb_coordinates', 'Town_City', 'Town_Suburb'], axis=1)
data.columns
# Out:
# Index(['NatEmis', 'Province', 'Official_Institution_Name', 'STATUS', 'Sector',
#        'Phase_PED', 'Specialisation', 'GIS_Long', 'GIS_Lat',
#        'District Mun Name', 'Local MunName', 'Ward_ID', 'StreetAddress',
#        'Telephone', 'Section21', 'School Fees', 'Urban_Rural', 'Towns/suburb',
#        'suburb_Latitude', 'suburb_longitude'],
#       dtype='object')

# %%
# Strip unwanted characters
data['suburb_Latitude'] = data['suburb_Latitude'].str[1:]
data['suburb_longitude'] = data['suburb_longitude'].str[:-1]
data.head()
# Out:
#      NatEmis Province               Official_Institution_Name STATUS  \
# 0  700400770       Gt           Lynnwood Manor Private School   Open
# 1  700401072       Gt               Advanced College Brooklyn   Open
# 2  700400322       Gt             Nooitgedacht Akademie Skool   Open
# 3  700401082       Gt         Melwood Institute Of Technology   Open
# 4  700400787       Gt  British International College-Pretoria   Open
#
#         Sector            Phase_PED Specialisation   GIS_Long    GIS_Lat  \
# 0  Independent       Primary School       Ordinary  28.290307 -25.756580
# 1  Independent      Combined School       Ordinary  28.248905 -25.768852
# 2  Independent  Intermediate School       Ordinary  28.743439 -25.803851
# 3  Independent     Secondary School       Ordinary  28.191676 -25.742973
# 4  Independent     Secondary School       Ordinary  28.218095 -25.744145
#
#                            District Mun Name  \
# 0  City Of Tshwane Metropolitan Municipality
# 1  City Of Tshwane Metropolitan Municipality
# 2  City Of Tshwane Metropolitan Municipality
# 3  City Of Tshwane Metropolitan Municipality
# 4  City Of Tshwane Metropolitan Municipality
#
#                                Local MunName   Ward_ID  \
# 0  City Of Tshwane Metropolitan Municipality  79900046
# 1  City Of Tshwane Metropolitan Municipality  79900082
# 2  City Of Tshwane Metropolitan Municipality  79900105
# 3  City Of Tshwane Metropolitan Municipality  79900058
# 4  City Of Tshwane Metropolitan Municipality  79900092
#
#                                    StreetAddress  Telephone Section21  \
# 0  99, Brampton Street, Lynnwood Manor, Pretoria  123489998        No
# 1           415, Marais Road, Brooklyn, Pretoria  120301031        No
# 2  17, Mark Street, Nooitgedacht, Bronkhorspruit  732577542        No
# 3     274,  Johannes Ramokhoase Street, Pretoria  123270294        No
# 4         774, Church Street, Eastwood, Pretoria  117067775        No
#
#   School Fees Urban_Rural      Towns/suburb suburb_Latitude suburb_longitude
# 0         Yes       Urban    Lynnwood Manor     -25.7630556       28.2811111
# 1         Yes       Urban         Brooklyn         -25.7646          28.2393
# 2         Yes       Urban  Bronkhorstspruit        -25.8084          28.7081
# 3         Yes       Urban  Pretoria Central     -25.7518426       28.1899743
# 4         Yes       Urban          Eastwood        -25.7411          28.2198

# %%
# Check for datatypes
print(data.dtypes)
# Out:
# NatEmis                        int64
# Province                      object
# Official_Institution_Name     object
# STATUS                        object
# Sector                        object
# Phase_PED                     object
# Specialisation                object
# GIS_Long                     float64
# GIS_Lat                      float64
# District Mun Name             object
# Local MunName                 object
# Ward_ID                        int64
# StreetAddress                 object
# Telephone                      int64
# Section21                     object
# School Fees                   object
# Urban_Rural                   object
# Towns/suburb                  object
# suburb_Latitude               object
# suburb_longitude              object
# dtype: object

# %%
# Change the town coordinates datatype from object to float
data['suburb_Latitude'] = pd.to_numeric(data['suburb_Latitude'], errors='coerce')
data['suburb_longitude'] = pd.to_numeric(data['suburb_longitude'], errors='coerce')
print(data.dtypes)
# Out:
# NatEmis                        int64
# Province                      object
# Official_Institution_Name     object
# STATUS                        object
# Sector                        object
# Phase_PED                     object
# Specialisation                object
# GIS_Long                     float64
# GIS_Lat                      float64
# District Mun Name             object
# Local MunName                 object
# Ward_ID                        int64
# StreetAddress                 object
# Telephone                      int64
# Section21                     object
# School Fees                   object
# Urban_Rural                   object
# Towns/suburb                  object
# suburb_Latitude              float64
# suburb_longitude             float64
# dtype: object

# %%
# Check for null values
print(data.isna().sum())
# Out:
# NatEmis                      0
# Province                     0
# Official_Institution_Name    0
# STATUS                       0
# Sector                       0
# Phase_PED                    0
# Specialisation               0
# GIS_Long                     0
# GIS_Lat                      0
# District Mun Name            0
# Local MunName                0
# Ward_ID                      0
# StreetAddress                0
# Telephone                    0
# Section21                    0
# School Fees                  0
# Urban_Rural                  0
# Towns/suburb                 0
# suburb_Latitude              0
# suburb_longitude             0
# dtype: int64

# %%
suburbs_town_df = data[['Province', 'Towns/suburb','suburb_Latitude', 'suburb_longitude']].copy()
suburbs_town_df.head(2)
# Out:
#   Province    Towns/suburb  suburb_Latitude  suburb_longitude
# 0       Gt  Lynnwood Manor       -25.763056         28.281111
# 1       Gt       Brooklyn        -25.764600         28.239300

# %%
# Pretoria Coordinates
latitude = -25.7479
longitude = 28.2293

# %% [markdown]
# ##### Map of Suburbs/Towns

# %%
suburb_data = suburbs_town_df
map_pretoria = folium.Map(location=[latitude, longitude], zoom_start=11)

# add markers to map
for lat, lng, label in zip(suburb_data['suburb_Latitude'], suburb_data['suburb_longitude'], suburb_data['Towns/suburb']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_pretoria)

map_pretoria
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c69cb01fab5a15d40a54501d0047ab36 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c69cb01fab5a15d40a54501d0047ab36&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c69cb01fab5a15d40a54501d0047ab36 = L.map(
#                 &quot;map_c69cb01fab5a15d40a54501d0047ab36&quot;,
#                 {
#                     center: [-25.7479, 28.2293],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 11,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_14e7ddbfe68c7678e80fd89702229249 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_14e7ddbfe68c7678e80fd89702229249.addTo(map_c69cb01fab5a15d40a54501d0047ab36);
#
#
#             var circle_marker_153aff8ed7bac5345e945d80783ad7a4 = L.circleMarker(
#                 [-25.7630556, 28.2811111],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3186cc&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_c69cb01fab5a15d40a54501d0047ab36);
#
#
#         var popup_827fbe6d33a6176618578a795d34a163 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_25288d7d2d9e8309620cc9342cadb523 = $(`&lt;div id=&quot;html_25288d7d2d9e8309620cc9342cadb523&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Lynnwood Manor&lt;/div&gt;`)[0];
#                 popup_827fbe6d33a6176618578a795d34a163.setContent(html_25288d7d2d9e8309620cc9342cadb523);
#
#
#
#         circle_marker_153aff8ed7bac5345e945d80783ad7a4.bindPopup(popup_827fbe6d33a6176618578a795d34a163)
#         ;
#
#
#
#
#             var circle_marker_25663ed88d8388628a44f2b2c17f0a50 = L.circleMarker(
#                 [-25.7646, 28.2393],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3186cc&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_c69cb01fab5a15d40a54501d0047ab36);
#
#
#         var popup_4c2c6bb41034bc5dec6b3aad3cd47fbf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_100d8956d5a394103febc8b16469ceec = $(`&lt;div id=&quot;html_100d8956d5a394103febc8b16469ceec&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Brooklyn &lt;/div&gt;`)[0];
#                 popup_4c2c6bb41034bc5dec6b3aad3cd47fbf.setContent(html_100d8956d5a394103febc8b16469ceec);
#
#
#
#         circle_marker_25663ed88d8388628a44f2b2c17f0a50.bindPopup(popup_4c2c6bb41034bc5dec6b3aad3cd47fbf)
#         ;
#
#
#
#
#             var circle_marker_93316b5daa29391b8d1a06e8969523fb = L.circleMarker(
#                 [-25.8084, 28.7081],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3186cc&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_c69cb01fab5a15d40a54501d0047ab36);
#
#
#         var popup_9f6a4bfddd76130646ee876c4e324e95 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5c01560d827533e55d483a087a39c69d = $(`&lt;div id=&quot;html_5c01560d827533e55d483a087a39c69d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Bronkhorstspruit&lt;/div&gt;`)[0];
#                 popup_9f6a4bfddd76130646ee876c4e324e95.setContent(html_5c01560d827533e55d483a087a39c69d);
#
#
#
#         circle_marker_93316b5daa29391b8d1a06e8969523fb.bindPopup(popup_9f6a4bfddd76130646ee876c4e324e95)
#         ;
#
#
#
#
#             var circle_marker_018b0cb5b4f02f1177f2513946bd9d18 = L.circleM

# %%
data.columns
# Out:
# Index(['NatEmis', 'Province', 'Official_Institution_Name', 'STATUS', 'Sector',
#        'Phase_PED', 'Specialisation', 'GIS_Long', 'GIS_Lat',
#        'District Mun Name', 'Local MunName', 'Ward_ID', 'StreetAddress',
#        'Telephone', 'Section21', 'School Fees', 'Urban_Rural', 'Towns/suburb',
#        'suburb_Latitude', 'suburb_longitude'],
#       dtype='object')

# %%
school_data = data[['Province','Towns/suburb','suburb_Latitude','suburb_longitude','Official_Institution_Name', 'GIS_Lat', 'GIS_Long']].copy()

# %%
school_data.head()
# Out:
#   Province      Towns/suburb  suburb_Latitude  suburb_longitude  \
# 0       Gt    Lynnwood Manor       -25.763056         28.281111
# 1       Gt         Brooklyn        -25.764600         28.239300
# 2       Gt  Bronkhorstspruit       -25.808400         28.708100
# 3       Gt  Pretoria Central       -25.751843         28.189974
# 4       Gt          Eastwood       -25.741100         28.219800
#
#                 Official_Institution_Name    GIS_Lat   GIS_Long
# 0           Lynnwood Manor Private School -25.756580  28.290307
# 1               Advanced College Brooklyn -25.768852  28.248905
# 2             Nooitgedacht Akademie Skool -25.803851  28.743439
# 3         Melwood Institute Of Technology -25.742973  28.191676
# 4  British International College-Pretoria -25.744145  28.218095

# %% [markdown]
# ##### Map of Schools in Pretoria

# %%
map_schools = folium.Map(location=[latitude, longitude], zoom_start=11)

# add markers to map
for lat, lng, label in zip(school_data['GIS_Lat'], school_data['GIS_Long'], school_data['Official_Institution_Name']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=2,
        popup=label,
        color='red',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_schools)  
    
map_schools
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_51949f114ff8f24d09abbe9346be9ce3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_51949f114ff8f24d09abbe9346be9ce3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_51949f114ff8f24d09abbe9346be9ce3 = L.map(
#                 &quot;map_51949f114ff8f24d09abbe9346be9ce3&quot;,
#                 {
#                     center: [-25.7479, 28.2293],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 11,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b0be73e9dcd71837202bb37d26596851 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b0be73e9dcd71837202bb37d26596851.addTo(map_51949f114ff8f24d09abbe9346be9ce3);
#
#
#             var circle_marker_48d7bd69a287763e27dfc6f58f91de8c = L.circleMarker(
#                 [-25.75658, 28.290307],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3186cc&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_51949f114ff8f24d09abbe9346be9ce3);
#
#
#         var popup_ed9032d8fa16dd2e027920431df802c1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e9fed62a5086b420e7bbfca02a13c63d = $(`&lt;div id=&quot;html_e9fed62a5086b420e7bbfca02a13c63d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Lynnwood Manor Private School&lt;/div&gt;`)[0];
#                 popup_ed9032d8fa16dd2e027920431df802c1.setContent(html_e9fed62a5086b420e7bbfca02a13c63d);
#
#
#
#         circle_marker_48d7bd69a287763e27dfc6f58f91de8c.bindPopup(popup_ed9032d8fa16dd2e027920431df802c1)
#         ;
#
#
#
#
#             var circle_marker_748d568b62426337eebf4f7478bbee67 = L.circleMarker(
#                 [-25.768852, 28.248905],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3186cc&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_51949f114ff8f24d09abbe9346be9ce3);
#
#
#         var popup_359fc0c76e92da6156ad101a89708379 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d73a48f2d072f4b22a9e3eb64f32cf34 = $(`&lt;div id=&quot;html_d73a48f2d072f4b22a9e3eb64f32cf34&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Advanced College Brooklyn&lt;/div&gt;`)[0];
#                 popup_359fc0c76e92da6156ad101a89708379.setContent(html_d73a48f2d072f4b22a9e3eb64f32cf34);
#
#
#
#         circle_marker_748d568b62426337eebf4f7478bbee67.bindPopup(popup_359fc0c76e92da6156ad101a89708379)
#         ;
#
#
#
#
#             var circle_marker_0b93596845fadd80ddf87e6ef5ea4991 = L.circleMarker(
#                 [-25.803851318, 28.743439411],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3186cc&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_51949f114ff8f24d09abbe9346be9ce3);
#
#
#         var popup_721342697bc500b6edee2fc0646ad948 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c1ae6fb6101308de81b30e709fe3c732 = $(`&lt;div id=&quot;html_c1ae6fb6101308de81b30e709fe3c732&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Nooitgedacht Akademie Skool&lt;/div&gt;`)[0];
#                 popup_721342697bc500b6edee2fc0646ad948.setContent(html_c1ae6fb6101308de81b30e709fe3c732);
#
#
#
#         circle_marker_0b93596845fadd80ddf87e6ef5ea4991.bindPopup(popup_721342697bc500b6edee2fc0646ad948)
#         ;
#
#
#
#
#             var circle_m

# %%
from sklearn.neighbors import BallTree

# %%
X = data[['GIS_Lat', 'GIS_Long']].values
tree = BallTree(X, leaf_size=2)

# %%
def find_nearest_schools(suburb_name, k=3):
    # Find the suburb latitude and longitude
    suburb = data[data['Towns/suburb'] == suburb_name].iloc[0]
    suburb_lat, suburb_lon = suburb['suburb_Latitude'], suburb['suburb_longitude']
    
    # Query the BallTree for the k nearest schools
    _, idxs = tree.query([[suburb_lat, suburb_lon]], k=5)
    nearest_schools = data.iloc[idxs[0]][['Official_Institution_Name']]
    
    # Concatenate the names of the nearest schools into a single string with line breaks
    return '\n'.join(f"{i+1}. {name}" for i, name in enumerate(nearest_schools['Official_Institution_Name']))

# %%
find_nearest_schools('Pretoria Central')
# Out:
# '1. Tshwane Secondary School\n2. Greenwood College\n3. St Aquinas-Pretoria Campus\n4. Hamilton Primary School\n5. Loreto Convent School'

# %%
data.columns
# Out:
# Index(['NatEmis', 'Province', 'Official_Institution_Name', 'STATUS', 'Sector',
#        'Phase_PED', 'Specialisation', 'GIS_Long', 'GIS_Lat',
#        'District Mun Name', 'Local MunName', 'Ward_ID', 'StreetAddress',
#        'Telephone', 'Section21', 'School Fees', 'Urban_Rural', 'Towns/suburb',
#        'suburb_Latitude', 'suburb_longitude'],
#       dtype='object')

# %%
def get_closest_schools(suburb_name, data):
    # Filter the dataframe to include only the suburb of interest
    suburb_df = data[data['Towns/suburb'] == suburb_name]
    
    # Get the latitude and longitude of the suburb
    suburb_lat = suburb_df.iloc[0]['suburb_Latitude']
    suburb_lon = suburb_df.iloc[0]['suburb_longitude']
    
    # Create a list to hold the distances between the suburb and each school
    distances = []
    
    # Iterate over the schools in the dataframe
    for index, row in data.iterrows():
        # Get the latitude and longitude of the school
        school_lat = row['GIS_Lat']
        school_lon = row['GIS_Long']
        
        # Calculate the distance between the suburb and the school
        distance = geodesic((suburb_lat, suburb_lon), (school_lat, school_lon)).km
        
        # Add the distance to the list
        distances.append(distance)
    
    # Add a new column to the dataframe with the distances
    data['Distance'] = distances
    
    # Sort the dataframe by distance
    closest_schools = data.sort_values(by='Distance').head(5)
    
    # Create a map centered on the suburb
    map = folium.Map(location=[suburb_lat, suburb_lon], zoom_start=13)
    
    # Add a marker for the suburb
    folium.Marker(location=[suburb_lat, suburb_lon], popup=suburb_name).add_to(map)
    
    # Add markers for the closest schools
    for index, row in closest_schools.iterrows():
        folium.Marker(location=[row['GIS_Lat'], row['GIS_Long']], popup=row['Official_Institution_Name']).add_to(map)
    
    # Return the map
    return map

# %%
get_closest_schools('Brooklyn', data)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8582f1402cd76dc45024edd5d0064d50 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8582f1402cd76dc45024edd5d0064d50&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8582f1402cd76dc45024edd5d0064d50 = L.map(
#                 &quot;map_8582f1402cd76dc45024edd5d0064d50&quot;,
#                 {
#                     center: [-25.7646, 28.2393],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_559e03d694ff1723a66f91b0e9176177 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_559e03d694ff1723a66f91b0e9176177.addTo(map_8582f1402cd76dc45024edd5d0064d50);
#
#
#             var marker_8fa31fd98e8d1fdeaa475270a7b4e349 = L.marker(
#                 [-25.7646, 28.2393],
#                 {
# }
#             ).addTo(map_8582f1402cd76dc45024edd5d0064d50);
#
#
#         var popup_587e823fff0d34ac3c2092cc21161968 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_82b33bdf0ea856475cb58a53d8bb96e2 = $(`&lt;div id=&quot;html_82b33bdf0ea856475cb58a53d8bb96e2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Brooklyn&lt;/div&gt;`)[0];
#                 popup_587e823fff0d34ac3c2092cc21161968.setContent(html_82b33bdf0ea856475cb58a53d8bb96e2);
#
#
#
#         marker_8fa31fd98e8d1fdeaa475270a7b4e349.bindPopup(popup_587e823fff0d34ac3c2092cc21161968)
#         ;
#
#
#
#
#             var marker_afe10e8ba6f1e4f50b8819dc57e3a853 = L.marker(
#                 [-25.76358036, 28.24300309],
#                 {
# }
#             ).addTo(map_8582f1402cd76dc45024edd5d0064d50);
#
#
#         var popup_6ea37a9e491f50b1f11bd7f3e0117ce6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d4c3b5043ac894c8d311bc436a788dae = $(`&lt;div id=&quot;html_d4c3b5043ac894c8d311bc436a788dae&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Pretoria Preparatory School&lt;/div&gt;`)[0];
#                 popup_6ea37a9e491f50b1f11bd7f3e0117ce6.setContent(html_d4c3b5043ac894c8d311bc436a788dae);
#
#
#
#         marker_afe10e8ba6f1e4f50b8819dc57e3a853.bindPopup(popup_6ea37a9e491f50b1f11bd7f3e0117ce6)
#         ;
#
#
#
#
#             var marker_155e47e6f17ff85640d65a0bf4f42729 = L.marker(
#                 [-25.76444336, 28.2433069],
#                 {
# }
#             ).addTo(map_8582f1402cd76dc45024edd5d0064d50);
#
#
#         var popup_6f9ba75302d9d7fb568e3c0309673954 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d73926604301e3a921ab57987da2b2d4 = $(`&lt;div id=&quot;html_d73926604301e3a921ab57987da2b2d4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Brooklyn Primary School&lt;/div&gt;`)[0];
#                 popup_6f9ba75302d9d7fb568e3c0309673954.setContent(html_d73926604301e3a921ab57987da2b2d4);
#
#
#
#         marker_155e47e6f17ff85640d65a0bf4f42729.bindPopup(popup_6f9ba75302d9d7fb568e3c0309673954)
#         ;
#
#
#
#
#             var marker_7399a84e6780fcc3af921f8f0cbbe060 = L.marker(
#                 [-25.766248333, 28.232081667],
#                 {
# }
#             ).addTo(map_8582f1402cd76dc45024edd5d0064d50);
#
#
#         var popup_6fd078304d74558ecdefd0e41cfd49f4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_40e2201dd6f0a003bfe5f21383b3f3c1 = $(`&lt;div id=&quot;html_40e2201dd6f0a003bfe5f21383b3f3c1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Waterkloof House Preparatory&lt;/div&gt;`)[0];
#                 popup_6fd078304d74558ecdefd0e41cfd49f4.setContent(html_40e2201dd6f0a003bfe5f21383b3f3c1);
#
#
#
#         marker_7399a84e6780fcc3af921f8f0cbbe060.bindPopup(popup_6fd078304d74558ecdefd0e41cfd49f4)
#         ;
#
#
#
#
#             var marker_be8d989526d240584dee569712a3e64a = L.marker(
#                 [-25.755424135, 28.241804504],
#                 {
# }
#             ).addTo(map_8582f1402cd76dc45024edd5d0064d50);
#
#
#         var popup_0e11f6282ac32389c0afc19d638831f6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e963c568250205bd2106293a3845910b = $(`&lt;div id=&quot;html_e963c568250205bd2106293a3845910b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;St Mary&#x27;S Diocesan School For Girls&lt;/div&gt;`)[0];
#                 popup_0e11f6282ac32389c0afc19d638831f6.setContent(h
